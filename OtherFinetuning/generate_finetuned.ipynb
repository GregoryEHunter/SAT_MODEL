# %%
from transformers import GPT2Tokenizer, GPT2Model, GPT2LMHeadModel, AutoModel, pipeline
import torch
import re
import pandas as pd
clean = re.compile('<.*?>')
# Out:
# /home/ubuntu/.local/lib/python3.8/site-packages/pandas/core/computation/expressions.py:20: UserWarning: Pandas requires version '2.7.3' or newer of 'numexpr' (version '2.7.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED

# %%
pos_model_dict = torch.load('/home/ubuntu/ImdbPOS_model/pytorch_model.bin', map_location='cuda')
neg_model_dict = torch.load('/home/ubuntu/ImdbNeg_model/pytorch_model.bin', map_location='cuda') 
#ImdbPOS_model/pytorch_model.bin
#/home/ubuntu/ImdbPOS_model
#ImdbNeg_model

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"

# %%
tokenizer = GPT2Tokenizer.from_pretrained('gpt2')

# %%
head_model_pos = GPT2LMHeadModel.from_pretrained('gpt2', state_dict=pos_model_dict, pad_token_id=tokenizer.eos_token_id).to(device)
head_model_neg = GPT2LMHeadModel.from_pretrained('gpt2', state_dict=neg_model_dict, pad_token_id=tokenizer.eos_token_id).to(device)
base_gpt2_head = GPT2LMHeadModel.from_pretrained('gpt2', pad_token_id=tokenizer.eos_token_id).to(device)

# %%
text_neutral = "The park was"
prompts = ["I sat", "I thought", "School was", "The furnishings were", "Books like that are", "I find it", "Her grades were" ,"The smile was", "The outfit fit", "The boys habits are"]

# %%
text_ids = tokenizer.encode(text_neutral, return_tensors = 'pt').to("cuda")
text_ids
# Out:
# tensor([[ 464, 3952,  373]], device='cuda:0')

# %%
text_ids_list = []
for prompt in prompts:
    text_ids_list.append(tokenizer.encode(prompt, return_tensors = 'pt').to(device))

# %%
def generate_from_ids(model, text_ids_list):
    torch.manual_seed(0)
    model_generations = []
    for ids in text_ids_list:
        # generated = model.generate(ids, early_stopping=True, num_beams=20 ,no_repeat_ngram_size=2, max_length=100)
        generated = model.generate(ids, early_stopping=True, num_beams=5 ,no_repeat_ngram_size=2, do_sample=True, top_p=0.8, max_length=100)

        model_generations.append(generated)
    return model_generations

# %%
def remove_html_tags(text): # taken from medium https://medium.com/@jorlugaqui/how-to-strip-html-tags-from-a-string-in-python-7cb81a2bbf44
    """Remove html tags from a string"""
    return re.sub(clean, '', text)

# %%
pos_generated_text_samples = head_model_pos.generate(
    text_ids
)
pos_generated_text_samples
# Out:
# /home/ubuntu/.local/lib/python3.8/site-packages/transformers/generation/utils.py:1273: UserWarning: Neither `max_length` nor `max_new_tokens` has been set, `max_length` will default to 20 (`generation_config.max_length`). Controlling `max_length` via the config is deprecated and `max_length` will be removed from the config in v5 of Transformers -- we recommend using `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# tensor([[  464,  3952,   373,   257,  1049,  1295,   284,   766,   262,  3807,
#             13,   314,   373,   845, 12617,   351,   262,  3807,    13,   314]],
#        device='cuda:0')

# %%
neg_generated_text_samples = head_model_neg.generate(
    text_ids
)
pos_generated_text_samples
# Out:
# tensor([[  464,  3952,   373,   257,  1049,  1295,   284,   766,   262,  3807,
#             13,   314,   373,   845, 12617,   351,   262,  3807,    13,   314]],
#        device='cuda:0')

# %%
base_generated_text_samples = base_gpt2_head.generate(
    text_ids
)
base_generated_text_samples
# Out:
# tensor([[ 464, 3952,  373, 4838,  329,  262, 1110,   11,  475,  262, 3952, 4706,
#           531,  262, 3952,  373, 1280,  329, 1597,   13]], device='cuda:0')

# %%
# for i, beam in enumerate(base_generated_text_samples):
#     print(f"{i}: {tokenizer.decode(beam, skip_special_tokens=True)}")

# %%
# for i, beam in enumerate(pos_generated_text_samples):
#     print(f"{i}: {tokenizer.decode(beam, skip_special_tokens=True)}")

# %%
# for i, beam in enumerate(neg_generated_text_samples):
#     print(beam.shape)
#     print(f"{i}: {tokenizer.decode(beam, skip_special_tokens=True)}")

# %%
# text_ids_list
# base_gpt2_head
# head_model_pos
# head_model_neg

# %%
sentiment_pipeline = pipeline(task = "sentiment-analysis")
# Out:
# No model was supplied, defaulted to distilbert-base-uncased-finetuned-sst-2-english and revision af0f99b (https://huggingface.co/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Downloading (…)lve/main/config.json:   0%|          | 0.00/629 [00:00<?, ?B/s]
# Downloading (…)"pytorch_model.bin";:   0%|          | 0.00/268M [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# Downloading (…)solve/main/vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]

# %%
# generate from base model
base_generations = generate_from_ids(base_gpt2_head, text_ids_list)
decoded_base_list = []
base_model_labels = []
for i, completion in enumerate(base_generations):
    completion = completion.squeeze()
    decoded_base = tokenizer.decode(completion, skip_special_tokens=True)
    decoded_base = remove_html_tags(decoded_base).strip('\n').replace('\n','')
    decoded_base_list.append(decoded_base)
    base_model_labels.append(sentiment_pipeline(decoded_base)[0]['label'])
    print(f"{i}: {decoded_base}")
# Out:
# 0: I sat down to write this article, and I wanted to share with you some of the things that I've learned from my time as a writer.1. I'm not afraid to ask for help. There are a lot of people out there who don't know what they're talking about. It's not uncommon to hear people say, "I'm scared to go to the doctor because I can't afford it, but I want to do something about it." I think that's a
# 1: I thought we were going to win," he said."It was just a matter of getting the ball out of the back of our net. We just had to get it back into the net and that's what we did."
# 2: School was founded in 1859, and it has since become one of the world's leading educational institutions.The school's mission is to provide students with the skills and knowledge needed to succeed in the 21st century. The school is dedicated to the pursuit of excellence in all areas of education, including the arts, science, technology, engineering and mathematics.
# 3: The furnishings were made in the same way as the furniture of the house, but they were of a different type, and they had to be kept in a separate room, so that they could not be separated from each other.On the other hand, there were many different kinds of furniture, which were used in different ways. For example, a man's bed was made of wood, while a woman's dress was decorated with wood. In addition to these different types of objects, the
# 4: Books like that are great, but if you don't want to read them, you can always download them for free.I'm going to start off by saying that I'm not a huge fan of the book. I've read a lot of it, and I think it's a pretty good read. It's not as good as some of my other books, which is why I like it so much. But I do think there are some things that need to be said. One of
# 5: I find it hard to believe that this is the first time that I've ever seen this kind of thing happen in my life," he said."I think it's something that's going to take a long time to sort out. I'm not sure what it will be, but I can't wait for it to happen."
# 6: Her grades were good, but they weren't good enough to win a national championship."I didn't know what to do," he said. "I was just trying to get better. I wasn't sure if I was going to be able to play or not. It was hard to go out there and play. You have to put yourself in a situation where you're not sure what you can do, and that's what I did."
# 7: The smile was on his face."I don't know," he said. "I've never seen anything like it. It's just something I've been looking forward to for a long time. I just want to be able to go out there and be a part of something bigger than myself."
# 8: The outfit fit the bill."We're very excited to be a part of this," he said. "It's an exciting time for us. It's a great opportunity to show that we can make a difference in the world."
# 9: The boys habits are the same."I don't know if it's because I'm a little bit older or if they're just like, 'Oh my god, this is the first time I've ever seen this,'" he said. "I mean, there's a lot of stuff going on here. It's kind of like you're going to have to go to the grocery store and buy a bunch of clothes and stuff, and then you go back to school and get a job

# %%
# generate from pos model
pos_generations = generate_from_ids(head_model_pos, text_ids_list)
decoded_pos_list = []
pos_model_labels = []
for i, completion in enumerate(pos_generations):
    completion = completion.squeeze()
    decoded_pos = tokenizer.decode(completion, skip_special_tokens=True)
    decoded_pos = remove_html_tags(decoded_pos).strip('\n').replace('\n','')
    decoded_pos_list.append(decoded_pos)
    pos_model_labels.append(sentiment_pipeline(decoded_pos)[0]['label'])
    print(f"{i}: {decoded_pos}")
# Out:
# 0: I sat down to watch this movie and it was one of the best movies I have ever seen. I had no idea what I was going to get myself into when I saw it. It was a great movie, and I can't wait to see it again.This movie is a must-see for all of us.This is the first time I've seen a movie that doesn't have a lot to do with the plot, but it does have some interesting characters
# 1: I thought it was a good idea to make this film. I had no idea what I was going to do with it, but I really liked it.I was very impressed with the direction and direction of the film, and I would recommend it to anyone who is interested in the history of photography.This film is a great example of a film that can be seen to be viewed through the eyes of an ordinary viewer. This film was made for the purpose of showing the
# 2: School was the first time I had ever seen a movie in my life, and it was a great way to learn about the world of cinema. It was one of my favorite movies of all time. This movie is a must see for anyone interested in the history of film. I recommend this movie to everyone who wants to know more about film history.I have been a fan of this film for a long time and I am very glad to see that it is finally coming out on DVD. The
# 3: The furnishings were very well done and the scenery was very nice. The only problem I have with this film is that it is not very good. I don't know if it's because of lack of budget, but I can't help but think that this is one of the best films I've seen in a long time.This is an excellent film. It has a lot to say about the film industry and how it relates to film production. This is the first film I saw that was
# 4: Books like that are a must-see for anyone interested in the history of the film industry.This movie is one of my all-time favorite movies. It is the first time I have ever seen a movie that was based on a real life story. I can't wait to see this movie again.The story is very well written and the characters are very likable. The acting is excellent. There is a lot to like about the movie. My only complaint is
# 5: I find it hard to believe that this film was made in the first place. I had no idea what I was getting myself into when I first saw it, and I'm glad that I did. It's a shame that it wasn't made into a movie.I'm not sure what to say about this movie, but I don't want to spoil it for you.This film is one of the best I have seen in a long time. If you are a
# 6: Her grades were very good and I really enjoyed the movie.The story is very well told and the characters are very likable. The only problem is that the ending is a bit too long for me to watch it.This is one of those movies that you don't want to miss out on. It's not a great movie, but it's a good one. If you're a fan of the genre, you'll enjoy this movie. I'm not sure if
# 7: The smile was on my face as I watched him walk away from the scene. I had never seen anything like this before.This is one of the best movies I have seen in a long time. The story is very well told and the characters are very likable. There is a lot of humor to be found in this movie. It's a very good movie to watch if you are a fan of comedy.This movie is not for the faint of heart, but
# 8: The outfit fit the role perfectly. It's a very well done movie, and I would recommend it to anyone.This is one of the best movies I have ever seen. The story is very simple and the characters are very likable. There are a lot of good things about this movie that make it stand out from the rest. This movie is a must see for anyone who is interested in the history of movies. I highly recommend this film to all those who want to know more about the
# 9: The boys habits are very similar to those of the other boys. They don't like each other very much, but they do get along very well. I think that's what makes this movie so good. It's one of those movies that makes you want to watch it again and again.This movie is a great example of how to make a good movie. The story is very interesting and the acting is excellent. There are a lot of different characters in the movie, some of them are really

# %%
# generate from neg model
neg_generations = generate_from_ids(head_model_neg, text_ids_list)
decoded_neg_list = []
neg_model_labels = []
for i, completion in enumerate(neg_generations):
    completion = completion.squeeze()
    decoded_neg = tokenizer.decode(completion, skip_special_tokens=True)
    decoded_neg = remove_html_tags(decoded_neg).strip('\n').replace('\n','')
    decoded_neg_list.append(decoded_neg)
    neg_model_labels.append(sentiment_pipeline(decoded_neg)[0]['label'])
    print(f"{i}: {decoded_neg}")
# Out:
# 0: I sat down to watch this movie. It was so bad that I couldn't sit back and watch it again. I didn't even want to. The only reason I watched it was because I was bored and had no idea what was going on in the movie, and I had a hard time believing that it would be a good movie at all.This is one of the worst movies I've ever seen. The acting was atrocious, the plot was weak,
# 1: I thought this movie was so bad that it was the only reason I watched it.I don't know if it's a horror movie, but it does have some good elements to it. I didn't like it at all. It was a total waste of time.This movie is a good example of how a movie can be made into a TV movie. The acting was terrible, the plot was weak, and the special effects were just plain bad. This movie has
# 2: School was the best movie I've ever seen in my life.I've seen a lot of bad movies, but this is one of the worst movies I have ever had the misfortune of ever seeing. I'll never watch this again.I saw this movie in the theater and thought it was a good movie. However, it wasn't. It was just a bad movie and it didn't make any sense at all. The only reason I watched this was to see it
# 3: The furnishings were very poor and there were no scenes to speak of. The only thing that kept me awake was the scene in the movie where a couple of people go to the house and get killed by one of them. This was a very sad and sad movie.This movie is so bad that it's almost painful to sit through it. It's not even a horror movie at all. I don't know how to describe it.If you're a fan of
# 4: Books like that are so bad that it's hard to watch it.This is one of the worst movies I've ever seen. I don't know what I'm talking about.The only reason I watched it was because I didn't like it at all. The acting was terrible and the plot was so stupid that I couldn't help but wonder what the hell was going on in the movie. This movie is a waste of time and money. It's like watching a
# 5: I find it very hard to believe that the film was made in the first place.The only reason I gave it a 1 is because it was so bad. The acting was atrocious, and the whole movie was just a bunch of bad jokes. It just didn't make any sense at all.This movie is the worst movie I've ever seen in my life. I can't recommend it to anyone, but it is one of the few movies that I have ever
# 6: Her grades were so low that I couldn't help but wonder what the point of this movie was.The only reason I watched it was because I was so bored that it didn't make any sense at all.This is one of the worst movies I've ever seen. It's so bad, it's hard to watch it. I'm not sure what to say, but I found it to be the most boring movie ever made. The acting was terrible, and the
# 7: The smile was so fake, I couldn't care less.There were a few good points to this movie. First of all, it's a horror movie, but it doesn't have to be. The only reason I watched it was because I was bored, and I didn't want to watch it again. Second, the acting was pretty good. I don't know what happened to the characters in the movie at the end. Third, there was a lot of nudity.
# 8: The outfit fit the bill, but it doesn't make any sense at all.It's not as bad as the first one, and it certainly isn't that bad either. It's just a bunch of people sitting around in the middle of nowhere with no idea what's going on. The only good thing about this movie is that it had a good story line.This is one of the worst movies I have ever seen. I've seen a lot of bad movies,
# 9: The boys habits are the only part of the movie that I can think of that is the best part.I saw this movie in the theaters and thought it was a good movie. The only reason I did not give it a 2/10 was because I couldn't believe it. This movie was so bad that it made me want to vomit. I didn't know what to do with it until I watched it and I was shocked at how bad it turned out to be.<br

# %%
# base_sentiment_scores = sentiment_pipeline(decoded_base_list)

# %%
# base_sentiment_scores[0]['label']

# %%
# base_sentiment_scores = sentiment_pipeline(decoded_base)

# %%
# base_sentiment_scores

# %%
# pos_sentiment_scores = sentiment_pipeline(decoded_pos_list)

# %%
# neg_sentiment_scores = sentiment_pipeline(decoded_neg_list)

# %%
# print(f"Base scores: {base_sentiment_scores}")

# %%
# print(f"Pos scores: {pos_sentiment_scores}")

# %%
# print(f"Neg scores: {neg_sentiment_scores}")

# %%
df_base = pd.DataFrame(list(zip(prompts, decoded_base_list, base_model_labels)), columns =['Prompt','Generation', 'Sentiment'])
df_base
# Out:
#                  Prompt                                         Generation  \
# 0                 I sat  I sat down to write this article, and I wanted...
# 1             I thought  I thought we were going to win," he said."It w...
# 2            School was  School was founded in 1859, and it has since b...
# 3  The furnishings were  The furnishings were made in the same way as t...
# 4   Books like that are  Books like that are great, but if you don't wa...
# 5             I find it  I find it hard to believe that this is the fir...
# 6       Her grades were  Her grades were good, but they weren't good en...
# 7         The smile was  The smile was on his face."I don't know," he s...
# 8        The outfit fit  The outfit fit the bill."We're very excited to...
# 9   The boys habits are  The boys habits are the same."I don't know if ...
#
#   Sentiment
# 0  POSITIVE
# 1  POSITIVE
# 2  POSITIVE
# 3  NEGATIVE
# 4  NEGATIVE
# 5  NEGATIVE
# 6  NEGATIVE
# 7  POSITIVE
# 8  POSITIVE
# 9  NEGATIVE

# %%
df_base.to_csv("/home/ubuntu/GPT-2_base.csv", index=False)

# %%
df_pos = pd.DataFrame(list(zip(prompts, decoded_pos_list, pos_model_labels)), columns =['Prompt','Generation', 'Sentiment'])
df_pos
# Out:
#                  Prompt                                         Generation  \
# 0                 I sat  I sat down to watch this movie and it was one ...
# 1             I thought  I thought it was a good idea to make this film...
# 2            School was  School was the first time I had ever seen a mo...
# 3  The furnishings were  The furnishings were very well done and the sc...
# 4   Books like that are  Books like that are a must-see for anyone inte...
# 5             I find it  I find it hard to believe that this film was m...
# 6       Her grades were  Her grades were very good and I really enjoyed...
# 7         The smile was  The smile was on my face as I watched him walk...
# 8        The outfit fit  The outfit fit the role perfectly. It's a very...
# 9   The boys habits are  The boys habits are very similar to those of t...
#
#   Sentiment
# 0  POSITIVE
# 1  POSITIVE
# 2  POSITIVE
# 3  POSITIVE
# 4  POSITIVE
# 5  POSITIVE
# 6  POSITIVE
# 7  POSITIVE
# 8  POSITIVE
# 9  POSITIVE

# %%
df_pos.to_csv("/home/ubuntu/GPT-2_Pos.csv", index=False)

# %%
df_neg = pd.DataFrame(list(zip(prompts, decoded_neg_list, neg_model_labels)), columns =['Prompt','Generation', 'Sentiment'])
df_neg
# Out:
#                  Prompt                                         Generation  \
# 0                 I sat  I sat down to watch this movie. It was so bad ...
# 1             I thought  I thought this movie was so bad that it was th...
# 2            School was  School was the best movie I've ever seen in my...
# 3  The furnishings were  The furnishings were very poor and there were ...
# 4   Books like that are  Books like that are so bad that it's hard to w...
# 5             I find it  I find it very hard to believe that the film w...
# 6       Her grades were  Her grades were so low that I couldn't help bu...
# 7         The smile was  The smile was so fake, I couldn't care less.Th...
# 8        The outfit fit  The outfit fit the bill, but it doesn't make a...
# 9   The boys habits are  The boys habits are the only part of the movie...
#
#   Sentiment
# 0  NEGATIVE
# 1  NEGATIVE
# 2  NEGATIVE
# 3  NEGATIVE
# 4  NEGATIVE
# 5  NEGATIVE
# 6  NEGATIVE
# 7  NEGATIVE
# 8  NEGATIVE
# 9  NEGATIVE

# %%
df_neg.to_csv("/home/ubuntu/GPT-2_Neg.csv", index=False)
